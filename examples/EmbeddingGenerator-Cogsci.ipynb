# %% [markdown]
# # Generating Sentences with TreeRNNs
#
# This notebook goes through a minimal example of encoding one sentence into a distributed representation using a TreeRNN, and the using this distributed representation to generate another sentence using a different TreeRNN in reverse. To start, we'll do some data cleaning to make sure we have a good set of sentence pairs to train on. The main goal here is to remove sentences with mispelled words and oddities.

# %%
import enchant 
import random
import pickle
import numpy as np

from collections import namedtuple
from pysem.corpora import SNLI
from pysem.networks import DependencyNetwork
from pysem.generatives import EmbeddingGenerator

checker = enchant.Dict('en_US')
TrainingPair = namedtuple('TrainingPair', ['sentence1', 'sentence2', 'label'])

snli = SNLI('/home/pblouw/snli_1.0/')
snli.load_xy_pairs()

def repair(sen):
    tokens = DependencyNetwork.parser(sen)
    if len(tokens) > 15:
        return None
    for token in tokens:
        if not checker.check(token.text):
            return None
    return sen

def clean_data(data):
    clean = []
    for item in data:
        
        s1 = repair(item.sentence1)
        s2 = repair(item.sentence2)
        if s1 == None or s2 == None:
            continue
        else:
            clean.append(TrainingPair(s1, s2, item.label))
    
    return clean

# %%
clean_dev = clean_data(snli.dev_data)
clean_train = clean_data(snli.train_data)
clean_test = clean_data(snli.test_data)

# %%
print(len(clean_dev))
print(len(clean_test))
print(len(clean_train))
# Out:
# 4955
# 4839
# 306651

# %% [markdown]
# Next, we'll build a vocab from the set of cleaned sentence pairs.

# %%
def build_vocab(data):
    vocab = set()
    for item in data:
        s1 = item.sentence1
        s2 = item.sentence2
        
        t1 = DependencyNetwork.parser(s1)
        t2 = DependencyNetwork.parser(s2)
        
        for t in t1:
            if t.text not in vocab:
                vocab.add(t.text)
        for t in t2:
            if t.text not in vocab:
                vocab.add(t.text)

    return sorted(list(vocab))

data = clean_dev + clean_test + clean_train
vocab = build_vocab(data)

# %%
print(len(vocab))
# Out:
# 22555

# %% [markdown]
# Now we can check to see whether any words in our cleaned data are missing from our model of Word2Vec embeddings:

# %%
train_data = [d for d in clean_train if d.label == 'entailment'] # or d.label == 'neutral']
test_data = [d for d in clean_test if d.label == 'entailment'] # or d.label == 'neutral']
dev_data = [d for d in clean_dev if d.label == 'entailment'] # or d.label == 'neutral']

print(len(train_data))
print(len(test_data))
print(len(dev_data))
# Out:
# 106288
# 1666
# 1701

# %%
dim = 300
iters = 50
rate = 0.0006
batchsize = 10000

vectors = 'w2v_embeddings.pickle'

with open('w2v_dep_vocabs.pickle', 'rb') as pfile:
    subvocabs = pickle.load(pfile)

encoder = DependencyNetwork(dim=dim, vocab=vocab, pretrained=vectors)
decoder = EmbeddingGenerator(dim=dim, subvocabs=subvocabs, vectors=vectors)

for _ in range(iters):
    print('On iteration ', _)
    if _ == 45:
        rate = rate / 2.0
    if _ == 50:
        rate = rate / 2.0
    
    batch = random.sample(train_data, batchsize)te
    for sample in batch:
        s1 = sample.sentence1
        s2 = sample.sentence2

        encoder.forward_pass(s1)        
        decoder.forward_pass(s2, encoder.get_root_embedding())
        decoder.backward_pass(rate=rate)
        encoder.backward_pass(decoder.pass_grad, rate=rate)
# Out:
# On iteration  0
# On iteration  1
# On iteration  2
# On iteration  3
# On iteration  4
# On iteration  5
# On iteration  6
# On iteration  7
# On iteration  8
# On iteration  9
# On iteration  10
# On iteration  11
# On iteration  12
# On iteration  13
# On iteration  14
# On iteration  15
# On iteration  16
# On iteration  17
# On iteration  18
# On iteration  19
# On iteration  20
# On iteration  21
# On iteration  22
# On iteration  23
# On iteration  24
# On iteration  25
# On iteration  26
# On iteration  27
# On iteration  28
# On iteration  29
# On iteration  30
# On iteration  31
# On iteration  32
# On iteration  33
# On iteration  34
# On iteration  35
# On iteration  36
# On iteration  37
# On iteration  38
# On iteration  39
# On iteration  40
# On iteration  41
# On iteration  42
# On iteration  43
# On iteration  44
# On iteration  45
# On iteration  46
# On iteration  47
# On iteration  48
# On iteration  49

# %% [markdown]
# ## Simple Entailment Generation Examples
#
# This small amount of data probably isn't enough to generalize outside of the training set, so we'll first check how well the learned decoder is able to generate the entailments it has been trained on.

# %%
sample_trees = [d for d in test_data if 5 < len(d.sentence2.split()) < 10]
batch = random.sample(test_data, 10)

for sample in batch:
    s1 = sample.sentence1
    s2 = sample.sentence2
    randsen = random.choice(sample_trees)

    encoder.forward_pass(s1)
    decoder.forward_pass(s2, encoder.get_root_embedding())

    predicted = [node.pword for node in decoder.tree]
    true = [node.lower_ for node in decoder.tree]

    print('Sentence: ', s1)
    print('Predicted Entailment: ', ' '.join(predicted))
    print('Actual Entailment: ', ' '.join(true))
    
    decoder.forward_pass(randsen.sentence2, encoder.get_root_embedding())
    alternate = [node.pword for node in decoder.tree]
    print('Random Tree Entailment: ', ' '.join(alternate))
    print('')
# Out:
# Sentence:  A surfer is performing a jumping stunt in the ocean.
# Predicted Entailment:  a is in the ocean .
# Actual Entailment:  a person in the water .
# Random Tree Entailment:  a surfer and a surfboard is outside .
#
# Sentence:  The football player prepares to kick the ball.
# Predicted Entailment:  the player is playing the ball .
# Actual Entailment:  a person is playing a sport .
# Random Tree Entailment:  there playing a player playing outside to the football .
#
# Sentence:  The guitarist performs a rocking solo.
# Predicted Entailment:  the guitarist is performs
# Actual Entailment:  the musician is performing
# Random Tree Entailment:  two guitarist performs loud to perform her musician perform .
#
# Sentence:  A little boy playing outside on the cement.
# Predicted Entailment:  a boy playing on cement .
# Actual Entailment:  a boy is outside playing .
# Random Tree Entailment:  a little boy is playing on the cement cement .
#
# Sentence:  An elderly woman wearing a skirt is picking out vegetables at a local market.
# Predicted Entailment:  an woman is at a vegetables market .
# Actual Entailment:  this woman is on a shopping trip .
# Random Tree Entailment:  woman is vegetables at the vegetables .
#
# Sentence:  Several street vehicles pass by a traditional architecture style of Thailand.
# Predicted Entailment:  cars are are in a street in street .
# Actual Entailment:  vehicles are going down a street in thailand .
# Random Tree Entailment:  the many cars are in a street .
#
# Sentence:  Three adults are working in a garden near a fence in the yard.
# Predicted Entailment:  the three people are outside near a yard .
# Actual Entailment:  the three adults are outside in the garden .
# Random Tree Entailment:  the people are near a yard .
#
# Sentence:  Female gymnasts warm up before a competition.
# Predicted Entailment:  gymnasts are ready for a competition .
# Actual Entailment:  gymnasts get ready for a competition .
# Random Tree Entailment:  the gymnasts are are a competition .
#
# Sentence:  A man with ski poles and a large camping backpack treks through the snow.
# Predicted Entailment:  a man is is in a snow in snowy snow .
# Actual Entailment:  a man is trekking through the snow with ski poles .
# Random Tree Entailment:  a man is is a backpack .
#
# Sentence:  A man in a white shirt hiking over rocks and water.
# Predicted Entailment:  a man is is .
# Actual Entailment:  a man is hiking .
# Random Tree Entailment:  a man in a shirt is .

# %% [markdown]
# We can also generate entailments using randomly chosen trees for the decoding network structure. This doesn't work very well.

# %%
batch = random.sample(test_data, 20)

for sample in batch:
    s1 = sample.sentence1
    s2 = sample.sentence2
    randsen = random.choice(sample_trees)

    encoder.forward_pass(s1)
    decoder.forward_pass(s2, encoder.get_root_embedding())

    predicted = [node.pword for node in decoder.tree]
    true = [node.lower_ for node in decoder.tree]
    
    print('Sentence: ', s1)
    print('Predicted Entailment: ', ' '.join(predicted))
    print('Actual Entailment: ', ' '.join(true))

    decoder.forward_pass(randsen.sentence2, encoder.get_root_embedding())
    alternate = [node.pword for node in decoder.tree]
    print('Random Tree Entailment: ', ' '.join(alternate))
    print('')
# Out:
# Sentence:  Two women stand in a kitchen and wipe down trays
# Predicted Entailment:  two women are in the kitchen .
# Actual Entailment:  two women stand in a kitchen .
# Random Tree Entailment:  there are a women in the kitchen .
#
# Sentence:  A wet child stands in chest deep ocean water.
# Predicted Entailment:  a child is is in the water .
# Actual Entailment:  the child s playing on the beach .
# Random Tree Entailment:  a is standing in the water
#
# Sentence:  Two little boys are standing in a kitchen.
# Predicted Entailment:  the boys are not happy .
# Actual Entailment:  the kitchen is not empty .
# Random Tree Entailment:  the boys are are up a food .
#
# Sentence:  A couple sits in the grass.
# Predicted Entailment:  couple are outside .
# Actual Entailment:  people are outside .
# Random Tree Entailment:  a couple is are outside to their grass .
#
# Sentence:  3 people on plain boats smiling towards the camera.
# Predicted Entailment:  a are camera on the boat
# Actual Entailment:  3 smiling people on a boat
# Random Tree Entailment:  a are smiling in the boat .
#
# Sentence:  3 Olympic winners posing for a photo on an advertised background
# Predicted Entailment:  a people are posing their picture taken .
# Actual Entailment:  some people are having their photo taken .
# Random Tree Entailment:  a people posing for photo of a photo .
#
# Sentence:  The large white bird grazes the water.
# Predicted Entailment:  the bird is is the water
# Actual Entailment:  the bird is touching the water
# Random Tree Entailment:  one bird is is water in the water .
#
# Sentence:  A black dog with a blue collar is jumping into the water.
# Predicted Entailment:  a dog is is to get wet .
# Actual Entailment:  a dog is going to get wet .
# Random Tree Entailment:  a dog is is a black water .
#
# Sentence:  The dogs are playing on the bed.
# Predicted Entailment:  dogs playing together together .
# Actual Entailment:  dogs playing together inside .
# Random Tree Entailment:  the dog dogs playing a fun .
#
# Sentence:  These girls are having a great time looking for seashells.
# Predicted Entailment:  the girls looking together .
# Actual Entailment:  the girls are outside .
# Random Tree Entailment:  two girls are looking together at the seashells .
#
# Sentence:  Swimming in the wide blue ocean.
# Predicted Entailment:  person is swimming wet and swimming in ocean .
# Actual Entailment:  some is staying afloat and moving in water .
# Random Tree Entailment:  a swimming swimming outside in the blue ocean .
#
# Sentence:  A girl bounces in a bounce house.
# Predicted Entailment:  a girl is bounces indoors .
# Actual Entailment:  a girl is bouncing around .
# Random Tree Entailment:  a girl bounces indoors in a bounce house .
#
# Sentence:  People shopping for vegetables at an outdoor market.
# Predicted Entailment:  shopping shopping at market and shopping at the market .
# Actual Entailment:  people shopping for veggies and fruit at a market .
# Random Tree Entailment:  a shopping outside shopping at for market .
#
# Sentence:  a brown and black attack dog being trained by a man holding a stick
# Predicted Entailment:  a dog is being are by a dog .
# Actual Entailment:  a dog is being trained by a man .
# Random Tree Entailment:  a dog is are with a dog dog .
#
# Sentence:  The bears are facing each other with their mouths wide open.
# Predicted Entailment:  two bears are are in each other in other open .
# Actual Entailment:  two bears are looking at each other with mouths open .
# Random Tree Entailment:  two bears are are in open .
#
# Sentence:  A rescue worker searches with a flashlight under a slab in a ruined building.
# Predicted Entailment:  a worker is a heavy hole .
# Actual Entailment:  a worker searches a ruined building .
# Random Tree Entailment:  there is a person under a building .
#
# Sentence:  A big dog and a smaller dog fight over a piece of fabric.
# Predicted Entailment:  two is playing with a piece of fabric
# Actual Entailment:  two dogs fighting over a piece of fabric
# Random Tree Entailment:  a dog dog is over with a piece
#
# Sentence:  Band plays in tight quarters.
# Predicted Entailment:  a band is plays .
# Actual Entailment:  the band is playing .
# Random Tree Entailment:  a plays in tight tight tight .
#
# Sentence:  Numerous customers browsing for produce in a market.
# Predicted Entailment:  customers are browsing .
# Actual Entailment:  people are shopping .
# Random Tree Entailment:  the customers in market browsing produce .
#
# Sentence:  A man in a yellow shirt and helmet mountain biking down a dusty path.
# Predicted Entailment:  a man is is down a path .
# Actual Entailment:  a man is biking down a path .
# Random Tree Entailment:  there is a outdoors on shirt .

# %% [markdown]
# ## Generating Entailment Chains (i.e. Inferential Roles)
#
# We can also generate entailment chains by re-encoding a generated sentence, and then generating new sentence from the subsequent encoding. This is kind of neat because it allows us to distill what the model has learned in a network of inferential relationships between sentences. Philosophers sometimes argue that the meaning of sentences is determined by it's role or location in such a network.

# %%
s1 = 'A man curls up in a blanket on the street.'
s2 = 'A dog chases in a field.'
s3 = 'A frog is cold.'

def predict(encoder, decoder, s1, s2, s3):
    encoder.forward_pass(s1)
    decoder.forward_pass(s2, encoder.get_root_embedding())

    true = [node.lower_ for node in decoder.tree]
    predicted = [node.pword for node in decoder.tree]

    print('Sentence: ', s1)
    print('Predicted Entailment: ', ' '.join(predicted))

    encoder.forward_pass(' '.join(predicted))
    decoder.forward_pass(s3, encoder.get_root_embedding())

    predicted = [node.pword for node in decoder.tree]
    print('Next Prediction: ', ' '.join(predicted))
    print('')

predict(encoder, decoder, s1, s2, s3)
    
s1 = 'A group of Asian men pose around a large table after enjoying a meal together.'
s2 = 'Some people pose for a picture'
s3 = 'The group takes a picture.'

predict(encoder, decoder, s1, s2, s3)

s1 = 'Two police officers are sitting on motorcycles in the road.'
s2 = 'Two policemen sit on their bikes.'
s3 = 'The men have big guns.'

predict(encoder, decoder, s1, s2, s3)

s1 = 'Five people are playing in a gymnasium.'
s2 = 'Some people are competing indoors.'
s3 = 'Some people are inside.'

predict(encoder, decoder, s1, s2, s3)

s1 = 'A woman, whose face can only be seen in a mirror, is applying eyeliner in a dimly lit room.'
s2 = 'The woman applies eyeliner.'
s3 = 'The red woman applies green eyeliner.'

predict(encoder, decoder, s1, s2, s3)
# Out:
# Sentence:  A man curls up in a blanket on the street.
# Predicted Entailment:  a man is in the street .
# Next Prediction:  a man is outside .
#
# Sentence:  A group of Asian men pose around a large table after enjoying a meal together.
# Predicted Entailment:  a group eating at a table
# Next Prediction:  the group eating a food .
#
# Sentence:  Two police officers are sitting on motorcycles in the road.
# Predicted Entailment:  two officers are on their road .
# Next Prediction:  the officers are same road .
#
# Sentence:  Five people are playing in a gymnasium.
# Predicted Entailment:  the people are are indoors .
# Next Prediction:  the people are indoors .
#
# Sentence:  A woman, whose face can only be seen in a mirror, is applying eyeliner in a dimly lit room.
# Predicted Entailment:  a woman is makeup .
# Next Prediction:  a female woman woman physical makeup .

# %%
def condition(encoder, decoder, s1, s2, cond):
    encoder.forward_pass(s1)
    decoder.forward_pass(s2, encoder.get_root_embedding() + cond)

    true = [node.lower_ for node in decoder.tree]
    predicted = [node.pword for node in decoder.tree]
    print('Predicted Entailment: ', ' '.join(predicted))
    
s1 = 'A woman, whose face can only be seen in a mirror, is applying eyeliner in a dimly lit room.'
s2 = 'a blond woman applying eyeliner'
cond_sen = 'A person in a hooded shirt is photographing a woman.'
encoder.forward_pass(cond_sen)
cond = encoder.get_root_embedding()

print('Sentence: ', s1)
print('Conditioning Context: ', cond_sen)

encoder.forward_pass('')
condition(encoder, decoder, s1, s2, cond)   

s1 = 'A shirtless man sleeps in his blue boat out on the open waters.'
s2 = 'The red man is in the big boat.'
cond_word = 'fishing'
cond = encoder.vectors[cond_word]

print('')
print('Sentence: ', s1)
print('Conditioning Context: ', cond_word)

encoder.forward_pass('')
condition(encoder, decoder, s1, s2, cond)

s1 = 'Seven women stand and sit around a waters edge and one of them women sitting in the middle with her bare feet in the water drinks from a water bottle.'
s2 = 'a big man is on a boat.'
cond_sen = 'What is in the water bottle?'

encoder.forward_pass(cond_sen)
cond = encoder.get_root_embedding()

print('')
print('Sentence: ', s1)
print('Conditioning Context: ', cond_sen)

condition(encoder, decoder, s1, s2, cond)
# Out:
# Sentence:  A woman, whose face can only be seen in a mirror, is applying eyeliner in a dimly lit room.
# Conditioning Context:  A person in a hooded shirt is photographing a woman.
# Predicted Entailment:  a naked is taking face
#
# Sentence:  A shirtless man sleeps in his blue boat out on the open waters.
# Conditioning Context:  fishing
# Predicted Entailment:  a shirtless man fishing in the floating boat .
#
# Sentence:  Seven women stand and sit around a waters edge and one of them women sitting in the middle with her bare feet in the water drinks from a water bottle.
# Conditioning Context:  What is in the water bottle?
# Predicted Entailment:  the young people are in the water .

# %% [raw]
# ## Substitional Analysis
#
# Finally, it is also possible to examine the effect a given word or phrase has on entailment generation via substitutions. Essentially, this involves looking at the difference made to the most likely entailment when a given word or phrase in the input sentence is replaced with another word or phrase.

# %%
s2 = 'the dog is on her phone'
s3 = 'the dog is outside'
s4 = 'the dog is selling the bone'
s5 = 'a dog wearing some clothes is indoors'
s6 = 'a dog are inside a car'
s7 = 'the boy is red'
s8 = 'three people are indoors'
s9 = 'a boy is not indoors'

def sub_predict(encoder, decoder, s1, s2):
    
    encoder.forward_pass(s1)
    decoder.forward_pass(s2, encoder.get_root_embedding())

    true = [node.lower_ for node in decoder.tree]
    predicted = [node.pword for node in decoder.tree]

    print('Sentence: ', s1)
    print('Predicted Entailment: ', ' '.join(predicted))
    print('')    

    
s1 = 'A boy in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A girl in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A woman in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A boy in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s3)

s1 = 'A woman in a beige shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s3)

s1 = 'A man in a beige shirt is driving in a car.'
sub_predict(encoder, decoder, s1, s4)

s1 = 'A person in a beige shirt is selling her car.'
sub_predict(encoder, decoder, s1, s4)

s1 = 'A boy in a red shirt is waiting in a store.'
sub_predict(encoder, decoder, s1, s5)

s1 = 'Some men in red shirts are waiting in a store.'
sub_predict(encoder, decoder, s1, s6)

s1 = 'Many women in red shirts are waiting in a store.'
sub_predict(encoder, decoder, s1, s6)

s1 = 'A boy and a girl are waiting in a store.'
sub_predict(encoder, decoder, s1, s8)

s1 = 'A boy and a girl are waiting in a playground.'
sub_predict(encoder, decoder, s1, s8)

s1 = 'A boy in a red shirt is sleeping in a car.'
sub_predict(encoder, decoder, s1, s9)

s1 = 'A boy in a red shirt is waiting in a store.'
sub_predict(encoder, decoder, s1, s9)
# Out:
# Sentence:  A boy in a beige shirt is sleeping in a car.
# Predicted Entailment:  a boy is in his car
#
# Sentence:  A girl in a beige shirt is sleeping in a car.
# Predicted Entailment:  a girl is in her car
#
# Sentence:  A man in a beige shirt is sleeping in a car.
# Predicted Entailment:  a man sleeping in his car
#
# Sentence:  A woman in a beige shirt is sleeping in a car.
# Predicted Entailment:  a woman is in her car
#
# Sentence:  A boy in a beige shirt is sleeping in a car.
# Predicted Entailment:  a boy is asleep
#
# Sentence:  A woman in a beige shirt is sleeping in a car.
# Predicted Entailment:  a woman is asleep
#
# Sentence:  A man in a beige shirt is driving in a car.
# Predicted Entailment:  a man is driving a car
#
# Sentence:  A person in a beige shirt is selling her car.
# Predicted Entailment:  a person is selling a car
#
# Sentence:  A boy in a red shirt is waiting in a store.
# Predicted Entailment:  a boy wearing a shirt is indoors
#
# Sentence:  Some men in red shirts are waiting in a store.
# Predicted Entailment:  the men are in a store
#
# Sentence:  Many women in red shirts are waiting in a store.
# Predicted Entailment:  the women are in a store
#
# Sentence:  A boy and a girl are waiting in a store.
# Predicted Entailment:  two kids are indoors
#
# Sentence:  A boy and a girl are waiting in a playground.
# Predicted Entailment:  two kids are outside
#
# Sentence:  A boy in a red shirt is sleeping in a car.
# Predicted Entailment:  a boy is not outside
#
# Sentence:  A boy in a red shirt is waiting in a store.
# Predicted Entailment:  a boy is not indoors

# %%
for x in train_data:
    if ' not ' in x.sentence1 or ' not ' in x.sentence2:
        print(x.sentence1)
        print(x.sentence2)
        print('')
# Out:
# A dog jumps to catch a toy in the snow.
# An animal is jumping in a place that is not hot.
#
# A large woman in a blue jacket is looking irritated.
# a heavy set woman wearing a jacket is not happy.
#
# A little girl walking down a dirt road behind a group of other walkers.
# The girl is not at the head of the pack of people.
#
# A group of tourists are exploring the sight.
# The People are not from here.
#
# Two motorcyclist racing on an inclined track.
# The track in the picture is not perfectly flat.
#
# three people dressed in costumes on a stage.
# The people are not in normal clothing.
#
# Three people wearing costumes are standing around talking.
# The trio are not in normal clothes.
#
# A child in a blue jacket and black cap sits amongst flowers and candles.
# The child is not standing.
#
# several workers standing in a partially constructed building behind street sign
# The workers are near a building that has not been completed.
#
# A young girl is sitting on the ground surrounded by other people.
# The young girl is not alone.
#
# The gentlemen wait not speaking to one another.
# the gentlemen wait
#
# A girl trying not to get her picture taking on a college campus.
# There is a young woman in this picture.
#
# A young boy is sleeping.
# A child is not awake.
#
# Woman in pink top walking past 3 men sitting on the steps.
# The men are not walking.
#
# A man is sitting down and holding a young boy.
# The man is not alone.
#
# Three men on a scaffold erected outside a building.
# Three men outside are not on the ground.
#
# A man is bent over with his gloved hands in some kind of liquid.
# The man is not standing up.
#
# Two women are walking through an urban setting with camping equipment.
# The two women are carrying camping equipment but are not currently camping.
#
# A little girl holds a red balloon in front of a doorway.
# The balloon is not blue.
#
# The little girl is playing with her shoes off.
# A little girl is not wearing her shoes.
#
# The journey is temporarily delayed by mechanical malfunctions.
# Due to problems the journey can not continue.
#
# A neon gas station sign at night.
# The sun is not out.
#
# A man with white hair sitting.
# A person is not standing.
#
# Two dogs run through shallow water in a bay.
# The water is not deep.
#
# A shirtless man in dirty black boots dips his hands into a bucket.
# The man is not fully clothed.
#
# A group of people in uniform dress are walking around outside of the Olympics.
# The group of people are not standing still
#
# A man wearing glasses is staring off into space.
# The man is not paying attention.
#
# Two people are relaxing on a beach amidst lounge chairs
# The people are not moving on the sand outside.
#
# A man with dirty feet laying on a step outside.
# The man is not wearing shoes.
#
# A group of people wearing jeans walk in front of a business.
# Several individuals in pants are not sitting down.
#
# A guy without a shirt on climbing up the side of a rock.
# Someone is not fully clothed.
#
# A child shows other kids his still packaged toy.
# The child has not opened his toy.
#
# A child shows other kids his still packaged toy.
# A child has not removed the toy from the box.
#
# A young woman getting her haircut.
# The young woman is not alone.
#
# Two teenagers recline on a couch in a department store.
# The teenagers do not own the couch.
#
# Children and a woman play in a fountain.
# Some of the people in the picture are not dry.
#
# A woman teaching a young girl not to be afraid of puppies.
# The woman and girl played with dogs.
#
# A man is sitting on the ground welding something.
# There is a man who is not standing.
#
# Two girls in costumes sit on a sidewalk.
# Two girls are not in the middle of the road.
#
# Two men are cooking as a woman looks on.
# The woman is not cooking.
#
# Two young boys are digging in the sand with their hands.
# The two young boys are not using any tools to dig.
#
# Depressed man who does not know what to do.
# A man is sad.
#
# This photograph expresses intangible frustration.
# The photograph is not a drawing.
#
# The fruits should be treated with lemon juice when sliced to prevent oxidation.
# The fruits will oxidize if not covered in lemon juice.
#
# An old woman with a cane sits on a red bench.
# The lady is not walking.
#
# Two men in blue shirts stand in a tent area.
# Two men are not sitting.
#
# A man wearing brown is outside next to a bicycle
# A man is not inside
#
# A man drinking coffee does not notice a cat behind him.
# The man is drinking something.
#
# Two boys sit on a trampoline.
# The boys are not standing.
#
# A man with a purple tie is singing into a microphone.
# The man is not wearing a silver tie.
#
# Two children climbing on top of art.
# Kids are not behaving.
#
# A woman reads her book at a local city park.
# She is not illiterate.
#
# A girl laying down reading at a park with people minding their own business.
# The girl is not alone at the park.
#
# Three little boys playing with a ball in a park.
# The little boys are not at home
#
# Taxis are driving down the rad in the rain.
# The rain does not stop the taxis from driving.
#
# A man in blue shorts outside an ice cream shop.
# A man wearing clothes is not inside a building.
#
# The brown dog is laying down on a blue sheet.
# the dog is not standing.
#
# A hot air balloon has some trouble taking off.
# The hot air balloon take off is not smooth.
#
# The conductor was very agitated during the performance.
# The conductor was not happy.
#
# I am really not sure what this group is doing.
# This group is doing something confusing.
#
# A boy swimming who is wearing goggles.
# the boy does not have water in his eyes
#
# The blades of the scissors overlap.
# The scissors are not open.
#
# Triangular blue and red flags flutter in the wind.
# There are flags the are not on the ground
#
# Dirt biker just completing a jump on a race course.
# The dirt biker did not get hurt.
#
# A lady thinking that she should not have bought such a hideous purse.
# lady with a purse
#
# A woman with a rolling luggage waits on a sidewalk.
# The woman here is not in a boat.
#
# A red and white car is overturned on a dirt track.
# The car is not upright.
#
# The sky appears clear.
# There were not many clouds in the sky.
#
# Telephone wires are visible.
# Telephone wires are not invisible.
#
# A woman wearing a blue business suit sitting on a bench with 2 suitcases.
# A woman wearing a blue business suit is not moving
#
# A family looking under the hood of a car.
# The family is not in the living room.
#
# A man in a taxi waiting to go.
# The taxi is not going.
#
# A snowboarder is in the air after making a jump near some trees.
# The snowboarder is not on the ground.
#
# Girl in a thin rowboat leaving the dock of a lake.
# The girl in the rowboat is not fat.
#
# two children on a ride
# The child is not riding alone.
#
# The collared dog is jumping into the air.
# The animal is not on the ground.
#
# Students with backpacks are casually walking.
# The students are not in a hurry to get to their destination.
#
# A child in a sweatshirt and jean skirt squatting.
# A child is not standing.
#
# A large number of people walk around at an outdoor festival.
# The people are not indoors.
#
# Sad man wearing jeans sitting on front step.
# A man is not currently happy.
#
# A crowd sitting outside on beach towels.
# The crowd is not indoors.
#
# A woman talks on her cellphone while walking past a construction area.
# A woman is communicating with someone and is not sitting down.
#
# Three young girls are embracing each other and seem happy.
# Three girls are not sad
#
# A young boy lies almost prone on a structure resembling a whale.
# The boy is not walking
#
# a rock climber with it shirt off
# A rock climber is not wearing a shirt.
#
# Older man working in a factory not looking too excited about the photograph.
# The older man is working
#
# Two men are sitting on folding chairs on a patio and talking.
# Two men are not standing while talking.
#
# Two girls playing with plastic bags in a park.
# The girls are not playing with real toys.
#
# A blond woman dressed in black and red is running.
# The woman in the picture is not standing still.
#
# Old woman in white and redhead cover.
# the woman is not young
#
# Two women are standing in a store with a baby in a blue stroller.
# the women are not at home
#
# Barefoot worker on chair laying out roofing for small garden enclosure.
# The worker is not wearing shoes.
#
# A young boy in a paper crown is sitting in a shopping basket.
# A young boy that is not older than 18 is sitting.
#
# A snowboarder glides through the air.
# The snowboarder is not sitting still.
#
# The water is very clear.
# The water is not polluted.
#
# A woman in a yellow top is standing with her hands on her hips.
# A woman is not happy.
#
# Two people riding a bicycle.
# Two people are not being still.
#
# A tall and bored looking man is just standing around doing nothing.
# The man is not talking.
#
# People walking on the sidewalk of a large city while traffic goes by.
# People are not running on the sidewalks.
#
# A skier wearing yellow and black is airborne.
# The person is not touching the ground.
#
# Three young men on a boat with no life jackets.
# Three men not wearing life jackets are on a boat.
#
# A bunch of kids in a classroom not doing any work.
# A bunch of kids just sitting in a classroom.
#
# A woman in a dark jacket sitting n a bus.
# The bus is not empty.
#
# Some construction workers are on a platform doing work to a building.
# The construction workers are not on the ground.
#
# Four young kids are sitting on large stools at a bar waiting for drinks
# Four kids are not standing.
#
# A brown and white dog is walking through a grassy field.
# The dog is is not paralyzed.
#
# A truck with an advertising billboard stuck in the middle of the road.
# An advertising vehicle is not moving in the road.
#
# A parent and child sitting together.
# Two people are not standing.
#
# A man sitting by a statue of a man at a laptop computer.
# A man is not standing by a statue
#
# A man in a green shirt and fatigues is fixing his bed
# The bed is not finished being made.
#
# Two young woman enjoying the night life.
# The women are not at home.
#
# Four young guys jumping down a stairway.
# The four young guys are not walking down the stairwell.
#
# My date is not coming on time.
# date is late
#
# An elderly man walks his bike containing items.
# The bike is not empty of items.
#
# A guy is reading a newspaper.
# The guy is not illiterate
#
# A man shaves his neck but not his beard.
# A man has a beard.
#
# A man wearing a blue helmet is on a motorcycle.
# A man is not in a car.
#
# A man walking across a chain over top of water.
# A man is not in the water.
#
# Three boys without shirts sit on concrete steps next to water.
# They are not wearing shirts
#
# Three shirtless men sitting on a wall next to water.
# The men are not fully dressed.
#
# A man dressed as a prisoner being punished for not having a permit.
# The man is in prison.
#
# A boy in a bathing suit serves a volleyball.
# The boy is not wearing formal church clothes in this picture.
#
# A girl with her arm around a boy covering his face.
# A girl is close to a boy whose face is not shown.
#
# A man in a cowboy hat rides a brown horse.
# A man is not standing without moving.
#
# Two people are climbing and outdoor artificial climbing wall.
# The two people are not on the ground.
#
# A man in a red jacket is reunited with a woman.
# A man and woman have not seen each other for a while.
#
# A little girl in a yellow shirt is standing covering her eyes.
# The girl does not want to look.
#
# cheerleaders taking a break
# The cheerleaders are not currently performing.
#
# A brown and white dog stands outside while it snows.
# The dog is not inside.
#
# A boy sitting on a bench with his feet placed on a skateboard.
# Someone who is shown does not have their feet on the ground right now.
#
# An old customer waits for his food from a vendor.
# The customer is not a young person.
#
# young girl kneels on a grassy field filled with candles
# The young girl is not standing up straight.
#
# A little girl with a yellow shirt and black shorts standing on a bed.
# She was not sitting down.
#
# A cyclist braces for impact as his bike loses control.
# The cyclist is not pedaling.
#
# Two friends holding hands as the walk the streets of a city.
# The picture does not place on a plane
#
# Two women who did not aim the camera at their faces.
# The two women did not aim the camera.
#
# A woman is riding her bicycle.
# The woman is not walking.
#
# A elderly man standing at the counter of an establishment.
# The man is not at home.
#
# The warmly dressed man and woman stand together outside.
# The two people are not sitting.
#
# A group of people seated in a line of seats at an event.
# A group of people are not walking.
#
# Two parents and a young girl blow up a raft.
# The raft is not yet inflated.
#
# Woman in nice clothes does not have an umbrella.
# woman without umbrella
#
# A man with a red shirt and glasses holding a newspaper in a building.
# The man does not have perfect vision.
#
# A stout gentleman does not know how to use his umbrella.
# A fat man is struggling with his umbrella.
#
# a young man without a shirt is wiping something
# The man is not wearing a shirt.
#
# A girl is standing barefoot on the railroad tracks
# The girl does not have footwear on.
#
# A shirtless toddler is sleeping with his hand on his chest.
# The toddler is not awake.
#
# A man in a hot spring tub smiling with no shirt.
# A man not wearing a shirt.
#
# A girl kneeling down in what appears to be a church.
# The girl is not standing up.
#
# Two girls dressed in Asian costumes are dancing barefoot.
# The girls are not wearing shoes.
#
# A white dog is splashing through the water.
# A dog is not dry.
#
# The man in the yellow canoe is in a large wave.
# the water is not still
#
# A man in yellow standing between two waterfalls.
# He is not under a waterfall
#
# A man in a blue shirt is kissing a woman in a red shirt.
# The individuals here are not dressed identically.
#
# A man carrying a bicycle.
# The bicycle is not touching the ground.
#
# An elderly woman is sitting down on the stone steps leading to impressive stonework.
# The elderly woman is not standing up.
#
# An older man is kicking an object.
# The man is not young.
#
# A man is riding his bicycle downhill in rough terrain.
# The man is not on a bike path.
#
# Baby not wearing any clothing eating a meal on a green tray outside.
# Baby not wearing any clothing
#
# A construction worker pointing to an object or area not seen in photo.
# A person points.
#
# An Asian girl has parked her bicycle.
# She is not riding her bike.
#
# A man is standing with a cup in his hand.
# A person is not sitting down.
#
# A man in black shirt is just relaxing.
# The man is not working.
#
# A small girl is sitting on the bleachers upset.
# The girl is not super tall.
#
# A group of tourists are standing on a bridge.
# The people are not from that area.
#
# Five girls are in front of a wall.
# The five girls are not in an airplane
#
# Baby sitting at a beach.
# The baby is not crawling.
#
# Two black males in front of a rickshaw.
# The males are not white.
#
# A woman is standing on the deck of a boat while holding a weight.
# The woman is not inside.
#
# A shiny brown motorcycle being viewed by a few people.
# The motorcycle is not being ridden
#
# Two dogs running in a field of dry grass on a clear day.
# Two dogs are running outside with not a cloud in the sky.
#
# The woman wearing the scarf is quietly waiting for the train.
# A female is not talk talking.
#
# A young child jumping on the bed as a man looks the other way.
# A kid not listening to his parent.
#
# A young girl hangs from the mounting beam of a basketball hoop.
# A young girl is not touching the ground.
#
# An older man poses near wooden bowls on display.
# The bowls are not made of metal or plastic
#
# Hipster performs on the acoustic guitar.
# The guitar is not electric.
#
# Raining outside and three black umbrellas and one yellow and pink umbrella.
# The umbrellas here are not all the exact same color.
#
# The young people have plenty of snacks close at hand.
# The young people will not go hungry.
#
# A man doing handstand on top of a round statue.
# The man is not standing on his feet.
#
# A gray dog climbs up a slanted tree.
# The dog is not on the ground.
#
# Three teenagers out at night.
# The three teenagers are not at home.
#
# A bird sitting on a telephone line.
# The bird is not flying.
#
# A skateboarder is skating down a very steep ramp in a skate park.
# The skater is not on flat ground.
#
# A man is riding a motorcycle in traffic.
# A man is not currently walking.
#
# The man and woman are sitting together and smiling.
# The man and woman are not standing up.
#
# A very pale redheaded teen has her hand to her face thinking.
# The teen does not have black hair.
#
# A man with a guitar is waving.
# The man is not playing the guitar
#
# A dedicated worker working on his craft shirtless.
# Someone not wearing a shirt is performing a task.
#
# A lady and a toddler stare at themselves in a mirror.
# The woman is not blind.
#
# A priest on the phone near some female military workers taking a break.
# The person is not wearing a baseball hat.
#
# The food needs to be eaten soon.
# The food will go bad if it is not consumed soon enough.
#
# Brightly dressed men doing acrobatics on a log.
# The clothes the men are wearing or not subtle or muted.
#
# An elderly gentleman very smartly dressed.
# The man is not young.
#
# Two men are sitting on their bags while other people walk in the background.
# The man is not standing.
#
# A brown dog is running.
# The dog is not walking.
#
# A red desk chair has been rolled away from the desk.
# The desk does not have a chair anymore.
#
# Mom is putting a very unhappy baby in the car seat.
# The baby in the car is not happy.
#
# A white dog with black spots jumps in midair.
# The dog is not touching the ground
#
# A street performer entertains tourists with a fake bird in a cage.
# The bird in the cage is not real.
#
# A dog standing on the side of a mountain.
# Some of the animals here are not rats.
#
# A worker is sitting down near a saw.
# The tool is not being used.
#
# A man wears an orange hat and glasses.
# the mans face is not completely visible.
#
# A bicyclist sitting down with his bike which has one wheel removed from it.
# A bicyclist is not riding his bike.
#
# A man with curly hair is sleeping.
# There is a man who is not entirely bald.
#
# The animals do not look aggressive.
# There is more than one animal.
#
# The animals do not look aggressive.
# The animals seem friendly.
#
# The animals do not look aggressive.
# The animals look peaceful.
#
# The animals do not look aggressive.
# The animals are calm.
#
# The animals do not look aggressive.
# The animals appear docile.
#
# The soil they walk on looks very dry.
# It is not raining
#
# The soil they walk on looks very dry.
# The soil has not been watered for a long time.
#
# A man is jumping over a water fountain.
# The man is not standing on the ground.
#
# A man and a woman standing on a street corner.
# A street corner is not empty.
#
# A group of men sitting on red chairs.
# The group of men are not standing.
#
# This woman is laying on concrete.
# The woman is not standing.
#
# A bicycle rider flies over a hill while a competitor is not far behind.
# A bike rider airborne over a hill with a competitor behind.
#
# A dirt bike racer jumping off a hill with another racer not far behind.
# The person on the motorcycle is jumping in the air.
#
# An Asian child looking towards something wearing traditional clothing.
# The clothing is not modern style.
#
# Two people stand at the peak of a mountain.
# Two people are not currently sitting down.
#
# A shirtless man in blue pants repairs a steel tea pot.
# The man is not wearing a shirt.
#
# A barefooted elderly man sleeping on a bench.
# A person is not awake.
#
# A man on scaffolding working in a tunnel.
# He is not on the ground
#
# Two girls trying to get to the bus station to go home.
# The girls are not at their home.
#
# A boy watching a mime with people around.
# A child is not alone while looking at a performance artist.
#
# A young lady reclines in a grungy basement full of fancy chairs.
# A woman is not standing.
#
# Boys all outside around a big bike.
# The boys are not inside.
#
# Football players gathering to contest something to collaborating officials.
# the football players do not agree with a ruling
#
# A blond woman leans against a white fence.
# The woman is not standing straight.
#
# A man with no shirt standing on a scaffolding.
# The man is not wearing a shirt.
#
# a young long girl climbing through a tunnel.
# The girl is not outside
#
# The man is holding a baby near a carnival game.
# The man is not going to win the carnival game.
#
# There are people outside at night on a camping trip.
# The people are not inside their tent or car.
#
# Nude child crawling on the beach while a man watches next to a horse.
# the child is not standing up
#
# A small child hangs from a wire fence.
# The little kid is not standing on the ground.
#
# A shirtless man is rock climbing on a vertical rock face.
# The man is not wearing a shirt.
#
# A young marathon runner leans on a railing.
# The man is not running in the picture.
#
# people enjoying a sunny day at the beach
# It is not raining.
#
# Many people have gathered to look at something that is not in the photo.
# A group of people are looking at something.
#
# A man is shooting fire from his mouth while holding a torch.
# The man is not fearful of fire.
#
# A man is sitting on a silver scooter.
# The man is not standing
#
# A woman in a pink shirt and shoes is looking at something.
# The woman is not blind
#
# A black and a brown dog are fighting.
# The 2 dogs are not getting along right now.
#
# What fun this is being caught in midair on a bike.
# The bike is not touching the ground.
#
# A man wearing a blue shirt with white stripes is doing work.
# The man is not sleeping.
#
# There are three people in jeans and shirts standing outside with spray cans.
# The people are not indoors.
#
# A man sitting on construction equipment behind a chain link fence
# A man not doing work
#
# People are sitting in the grass not wearing shirts.
# There are people in the grass.
#
# There is a restaurant and all the tables are empty.
# The restaurant is not busy.
#
# Clad in galoshes she balances making quick work of the task at hand.
# She is not working slowly.
#
# Young girl wearing a pink sweater sitting on a man.
# Young girl in a pink sweater is not standing
#
# A man in a blue shirt looks irritated.
# the man is not pleased
#
# The animals coexist peacefully.
# The animals are not bothering one another.
#
# two girls walking on the wall beside grass
# The girls are not on the grass.
#
# A woman holding a bowl of food in a kitchen.
# The bowl is not empty.
#
# A woman in a red dress is talking on a cellphone.
# Some people in the picture are not wearing jeans.
#
# Woman eating food on a table with raw meat on it.
# The table is not clean.
#
# A man is working on a steam engine in front of a water tower.
# The steam engine is not running.
#
# A barefooted woman spinning yarn on the floor.
# The woman is not wearing shoes.
#
# An empty seat at a Mexican themed restaurant.
# A restaurant is not full.
#
# A group of people protesting.
# A bunch of people are not happy and protesting.
#
# A man not wearing a shirt dancing by himself with his eyes closed.
# A shirtless man is dancing.
#
# A white car is parked by a wall with graffiti.
# The car is not moving.
#
# The small boy looks at the camera while other boys play ball behind him.
# The boy is not playing ball.
#
# Three people standing on a mountain about halfway to the top.
# They are not at the top yet
#
# An adorable baby boy sitting outside.
# A boy is not standing.
#
# Two Chinese boys by two soft drink machines.
# The boys do not have beards.
#
# A child holding a toy while walking on a lawn.
# The toy is not on the lawn
#
# One woman sitting on a sidewalk with others to the side and behind her.
# The woman is not alone on the sidewalk.
#
# Five women wearing skimpy red and black outfits pose.
# The women are not wearing much.
#
# Shirtless man sleeps under a window.
# The man does not have a shirt on.
#
# A young blond child playing
# The little kid does not have black hair.
#
# A woman is sitting on some steps and relaxing with her eyes closed.
# She is not looking around
#
# Food is prepared in an open air market.
# The market where the food is prepared is not enclosed.
#
# Two women and four children standing next to a brightly painted truck.
# The truck is not black
#
# A man with a bandage on his finger is rock climbing as others watch.
# The man is not on the floor.
#
# Two brothers in colorful outfits carrying water back to their home.
# The brothers are not at home.
#
# The security guard is smiling.
# The security guard does not seem upset or sad
#
# A man teaches a small class.
# There are not many in the class.
#
# A child is looking at an exhibit.
# A child is not blind.
#
# A man walks past a building with a door that says Keep Clear.
# The door is not obstructed
#
# A baby in a polka dot bib is not happy eating his soup.
# an unhappy baby
#
# Lots of people in different costumes at some kind of party.
# There are people who are not all wearing identical outfits.
#
# A young man sits with a dog outside.
# The people in the picture are not indoors.
#
# Cyclists are walking their bicycles through a tunnel.
# The people are currently not riding their bikes.
#
# A girls climbs on a jungle gym.
# The girl is not touching the ground.
#
# A man in a purple jacket has an expression on his face.
# The man in purple does not have blank look on his face.
#
# The girl is sleeping in the seat.
# The girl is not awake.
#
# two young women are both looking at their cellphones
# Two women are not looking at each other.
#
# Five young people smiling for picture and one child not facing front
# A photograph of six people.
#
# A photo of an arena with very few people in the stands.
# There are not many people in the stands.
#
# An elderly man sitting outside.
# An elderly man is not standing.
#
# A Golden Labrador is swimming through water with a red toy in its mouth.
# The dog is not afraid to go in the water.
#
# A mattress leaning on a telephone pole.
# The mattress is not on the bed.
#
# Four women stand upside down on their hands on a basketball court.
# The four women are not standing on their feet.
#
# An older man is leaning against the inside of a commuter bus.
# The older man is not sitting down.
#
# A brown and black dog is laying on a shaggy rug.
# The dog is not standing up.
#
# The mountain biker in blue rides down a rocky path.
# The mountain biker not on foot.
#
# The train is sitting at the train station with not too many passengers around.
# A train is sitting at the train station with not too many passengers around.
#
# The woman is wearing a necklace but has no other visible jewelry.
# The woman is not wearing a ring.
#
# It appears to be late fall or early winter.
# It does not appear to be summer.
#
# A big dog tied to a door.
# A pet is tied and is not able to move freely.
#
# A man plays solo guitar on the sidewalk at night.
# The man does not have a band with him.
#
# Dog playing with ball in dried up field
# The field is not moist
#
# construction workers appearing through a chain link fence.
# The constructions workers are not indoors.
#
# Man urinating out in public.
# A man is not using the bathroom
#
# A woman shows a child a loom.
# The child has not seen a loom before.
#
# A woman and a man getting closer.
# A woman and a man are not far away.
#
# Biker does a trick in midair.
# A person is not touching the ground.
#
# The image links are broken.
# The image links do not work.
#
# A young boy is sitting in a blue chair.
# The young boy is not standing in this picture.
#
# A man jumps his bicycle in the air between two rocks.
# The man is not standing on the ground.
#
# Many of the dishes contain rice.
# Some dishes do not have rice.
#
# A fisherman fishes at the bank of a foggy river.
# The river is not clear.
#
# A man is reading a novel while he is waiting at the laundromat.
# The man is not at his house.
#
# The man is white.
# The man is not black.
#
# A family together at the beach enjoying themselves.
# A family is not currently sitting inside a house.
#
# A young man watches a video at the mall.
# A man is not at his house.
#
# a lively city street at night.
# The sun is not out in the city.
#
# A biker is doing tricks on his bike.
# The biker is not just riding his bike in a normal fashion
#
# A group of people are waiting for a train to arrive.
# The train has not yet arrived.
#
# People waiting for the subway.
# The subway has not arrived yet.
#
# The little boy is playing by tires.
# He is not a grown adult.
#
# Toddler sits on carpet in living room touching guitar.
# The child is not sitting on a wooden or tiled floor.
#
# A hockey goalie is trying to prevent a goal from the opposing team.
# The goalie does not want the goal to go in.
#
# Many people sit at a long dinner table at a formal event.
# These folks are not at an informal occasion.
#
# The man and woman are sitting by the boats.
# The two people are not walking around.
#
# The cowboy in blue is trying not to be thrown off of the horse.
# The cowboy is riding a horse.
#
# A street corner has a few individuals waiting to cross.
# Street is not crowded.
#
# Two men not looking at pictures.
# Two men doing something.
#
# A few homeless men sit on a curb.
# The men in the picture do not live in large apartments.
#
# Old lady crosses the street in the city.
# The lady is not a teenager.
#
# two children play with food on a table.
# Two children are not eating the food.
#
# A child sitting on the ground.
# The child is not running
#
# An elderly man in a red jacket shielding his face from the sun.
# The elderly man is not as young as he used to be.
#
# A young Japanese man does not like his picture taken.
# A man obviously dislikes their picture being taken.
#
# A young Japanese man does not like his picture taken.
# There is an Asian man.
#
# A young Japanese man does not like his picture taken.
# A guy frowning.
#
# A boy with his arm wrapped in an ACE bandage rests in a bed.
# A boy is not currently standing.
#
# A man with longer hair is surfing.
# The man is not bald.
#
# A woman speaks into a bullhorn on a cold night.
# The woman is not in a warm place.
#
# A young boy walking his bicycle in the early evening.
# The boy is not riding his bicycle.
#
# A soccer player in the air after kicking the ball towards the defensive goalie.
# The soccer player is not on the ground.
#
# The room is carpeted.
# The floors in the room are not bare wood floors.
#
# A young lady looking disgusted wearing a blue shirt.
# a woman was not happy
#
# A woman standing with a bicycle.
# A woman is not currently sitting.
#
# A woman wearing blue and red walks through a rustic urban area.
# The woman is not riding a bike.
#
# Surveying or installing underground items in a grassy field.
# Items are not being installed in a dirt pile.
#
# A man throwing a green ball in front of a group of people.
# The man is not alone.
#
# A group of people watching a man looking up at streetlights.
# The picture does not take place in the middle of the ocean.
#
# A woman is looking at clothing.
# The woman is not blind.
#
# Adults and children gathered outdoors under a slatted roof socializing
# The people who are shown are not all the exact same age.
#
# Two young girls pose for a picture with one carrying the other.
# Two girls are not sleeping.
#
# A piece of heavy machinery sits in front of a hole.
# The big machine is not in the garage.
#
# A woman wearing jeans and a blue shirt is standing outside smoking a cigarette.
# The woman could not fit in her jeans earlier in the day.
#
# A person with cooking utilities poses menacingly in a dark environment.
# There is not much light in this environment.
#
# A man working in a dirty area.
# The man is not relaxing.
#
# Some ladies are laying down outside and using laptop computers.
# The ladies are not inside.
#
# A barefoot jogger in a park.
# A person is not wearing shoes outside.
#
# A person is squatting with a yellow umbrella on a beach.
# The person is not standing upright.
#
# A brown and white dog playing on grass.
# The dog in the picture is not all one color.
#
# A boy in red jumping into a sandbox.
# The boy is not scared of the sand.
#
# A man wearing suspenders poses outside.
# The person depicted is not indoors.
#
# An airline stewardess is carefully rolling her drink cart down the aisle.
# She is trying not to hit anything.
#
# Four men and one woman are sitting near each other.
# The people are not standing.
#
# A woman sitting at a table alone.
# The person sitting at a table does not have any company.
#
# Many people are sitting at tables under a large tent.
# There are multiple people not standing.
#
# Two women eat out at a restaurant
# The women are not home
#
# A young man stands against a tree drinking from a cup.
# The young man is not sitting down.
#
# A dog walking around with his leash but not with his owner.
# A dog is walking around.
#
# A toddler sitting on a pile of rocks holding a rock at a beach.
# A toddler is not currently walking.
#
# Several fire dancers participated in a ritual in front of onlookers.
# The dancers are not alone.
#
# A man sleeping alone on the side of the road.
# A person is not awake.
#
# Street scene with a man sat outside a closed and shuttered shop
# The shop is not open.
#
# Two man standing in front of a huge fountain with several background people.
# The men are not alone.
#
# Workers making dangerous icy steps not so dangerous.
# Some workers.
#
# A woman wearing a pink sweater is sleeping
# The woman is not awake.
#
# A woman is playing tennis while sitting down in the grass.
# The woman is not standing while playing tennis
#
# Man climbing a rock wall.
# The person is not standing on solid ground.
#
# A group of people stand in the snow in a mountain.
# Their feet are not visible
#
# A man in a blue shirt is fixing s boat.
# The man is not wearing a tuxedo.
#
# A man wearing red pants is balancing on a blue sculpture.
# The man is not falling
#
# A pretty young woman singing.
# The woman is not old.
#
# A couple waiting at a crosswalk in a brightly lit city.
# The people are not in the country.
#
# Two people with dreadlocks.
# There are humans who are not completely bald.
#
# Construction workers work on an old building.
# The building is not new.
#
# Group of young men posing and holding cans.
# The men are not standing casually.
#
# A crying child and people walking in a park.
# A child is not happy.
#
# Three teenagers outside walking down the street.
# The three teenagers are not in a school.
#
# Many people are at a shallow blue beach.
# The water is not very deep near the beach.
#
# A boy in a green sweater is sitting at a table.
# the boy is not walking
#
# Young people are working in a laboratory.
# The laboratory is not empty.
#
# A woman in the middle of throwing a blue football in a park.
# The football is not normal colored.
#
# Big dog trying to bite little dog
# The dogs did not like each other.
#
# A shirtless man jumps in a sunny forest.
# A man is not wearing a shirt.
#
# A group of young adults standing inside near a Pabst Blue Ribbon beer display.
# The group are not outside.
#
# One tan dog with a stick and one mostly black dog.
# The dogs are not identical.
#
# The lady is watching something she does not like.
# The lady does not like what she sees.
#
# Two women with backs to the camera.
# Some women are not facing the camera.
#
# People are sitting on benches in a plaza.
# The people are not standing.
#
# two people sit on a bench.
# There are multiple humans who are not standing.
#
# A smiling blond girl crawling into a moonwalk.
# The girl is not walking.
#
# The baseball game is being played on a cool semi cloudy night.
# The weather is not too hot.
#
# a man in a black shirt has his back towards a woman.
# He does not see the woman behind him
#
# An old man sits on a bench overlooking the water.
# The old man is not standing up.
#
# A man with a beard is sitting on red painted steps.
# The steps are not empty.
#
# The boy in swim trunks is laying face down on a watery pavement.
# The boy is not standing up.
#
# An elderly person in a field of hay.
# The person is not young.
#
# A mother and her young song enjoying a beautiful day outside.
# The mother and son are not inside
#
# A small boy dances on the concrete surrounded by adults.
# The boy is not alone.
#
# Four children with cowboy hats are sitting in the bleachers.
# The children are not standing.
#
# A few people with a girl standing up in the center wearing a green dress
# A girl in a dress is not alone.
#
# A girls is jumping in the sand.
# The girl is not inside the building.
#
# People are busy walking the street.
# The street is not empty.
#
# A man with a beard checks his cellphone while a lady looks on.
# The lady is not looking at the man.
#
# A man walking through an empty classroom.
# The classroom does not have students in it
#
# A small child grips onto the red ropes at the playground.
# The park is not empty.
#
# Women sitting on a bench waiting for her laundry
# The woman is not active.
#
# Construction worker welds in the dark.
# It is not bright in the welding location.
#
# A black dog and a spotted dog are fighting
# The dogs are not getting along.
#
# Two men giving another a haircut.
# A least one of the men is not bald.
#
# A man leans against a pole in a busy area.
# The area around the pole is not empty.
#
# Two guys are sitting and a lady is sleeping.
# Guys are not standing while a gal is not awake.
#
# A shirtless man is climbing a rock.
# The man does not have on a shirt.
#
# A shirtless man is rock climbing at a very steep angle.
# The man is not wearing a shirt.
#
# A guy skateboarding on midair.
# The skateboard is not on the ground.
#
# A man and woman standing looking at a picture the woman is holding.
# the man and woman are not sitting down
#
# A barber is giving a haircut to an elderly man outdoors.
# The elderly man is not bald.
#
# Two children are shown upside down.
# Kids are not right side up.
#
# a man walking around the corner of a red building.
# The man is not walking in a straight line.
#
# A group of people looking of in different directions trying to avoid the camera.
# People not looking at the camera.
#
# A group of people not wanting to take a picture.
# People are avoiding the camera.
#
# A little boy is jumping in front of a fountain.
# The boy does not have his drivers license yet.
#
# A man with a long mustache is playing an instrument outdoors.
# The man has not shaved his mustache in awhile.
#
# A man in a sweater is looking at dirty stairs.
# The stairs are not clean.
#
# A boy pets a sleeping tiger.
# A boy is touching an animal that is not awake.
#
# The girl in the yellow dress looks so cute.
# The girl is not wearing pants.
#
# Three young men are standing together outdoors near some stores.
# The men are not inside.
#
# A group of man standing together and one of them is holding a cane.
# The group of men are not sitting on the ground.
#
# A girl in vibrant colors is walking her bike in a dark area.
# A girl is not riding her bike.
#
# A man without shirt is working with woods.
# The man is not wearing a shirt
#
# A race car is drifting on the unpaved the road.
# The road does not have asphalt.
#
# Two young men are seated in front of a green pool of water.
# The men are not standing
#
# Four construction workers are working at night in the city by the water.
# The workers are not wearing bathing suits.
#
# A group of businessmen walking down the road.
# A group of business man not used their car.
#
# A black dog runs on the beach.
# The dog on the beach is not white.
#
# Two referees sitting on a bench in an empty field.
# The referees are not standing.
#
# Many Asian people move around a travel bus.
# Tourists on a transportation vehicle are not in their seats.
#
# Male magician doing a trick in front of an audience.
# A man is not currently alone.
#
# two women ran into each other on street.
# Two women are not at home.
#
# The student appears sullen as a man helps her position her sash.
# a student is not happy
#
# A lady who has fallen asleep hard at work.
# There is a person who is not conscious.
#
# A bald eagle stands in shallow water.
# A bird is not flying.
#
# A man in a white shirt sitting beside the road on a pole.
# The man is not naked.
#
# A crowd of people are standing and waiting in a busy area.
# The people are not sitting.
#
# A young man climbing up the side of a mountain while shirtless.
# A young man is not wearing a shirt.
#
# A man fishing in a boat with mountains in the background.
# The man is  not in an office.
#
# A man sitting on a huge rock to pose for a picture.
# The man is not standing up.
#
# Skateboarder not wearing a shirt does a cool trick.
# Skateboarder not wearing a shirt does a cool trick.
#
# A girl standing in the dark lighting something.
# A gal is not sitting.
#
# A woman with red shoes is standing in the middle of the street.
# A woman is not standing on the sidewalk.
#
# A brown dog walking on a frozen lake carrying a stick.
# This dog is not white with black spots.
#
# A wild animal not found in America jumping through a field.
# A wild animal is jumping through a field.
#
# A barefoot boy is crying.
# The boy is not wearing shoes.
#
# The plants or shrubs have not been trimmed and are overgrown.
# The plants have grown large without being tended.
#
# The plants or shrubs have not been trimmed and are overgrown.
# The plants are overgrown
#
# The plants or shrubs have not been trimmed and are overgrown.
# There are plants in the picture
#
# A man sitting on a panel not enjoying the speech.
# A man is not enjoying his time
#
# A policeman is on horseback nearby not looking at the men on the corner.
# The officer is a man.
#
# An invisible man in a suit holding a rainbow umbrella.
# You can not see this man.
#
# This is a good map for tourists.
# People not from this area would find this map useful.
#
# A young woman wearing a beautiful white ensemble looks flustered.
# The woman is not wearing ugly clothes.
#
# Shirtless man balancing on unfinished roof.
# Shirtless man is not on the ground
#
# A man in a suit is running across the street.
# The man is not dressed to run.
#
# Two boys in underwear play in the water in the city street.
# The two boys are not naked.
#
# A man on sailboat is happily displaying a marlin.
# The man is not sitting in his car.
#
# First responders look at car that has slid off a snowbank and flipped over.
# The weather in the picture is not warm at all.
#
# A group of people are outside waiting for the train.
# The train is not present.
#
# The little kid sits down in the muddy water.
# The water is not clear.
#
# Man in wheelchair and two men pushing him greeted by monk.
# The man is not standing
#
# Green bicycle sitting outside on sidewalk on display.
# The display is not empty.
#
# A guy in a costume.
# A guy not in normal clothes.
#
# Old man sitting on a red bench looking at a blank screen.
# The screen does not show anything.
#
# The dog is lying on the cobblestone street.
# A pet is not indoors.
#
# An unhappy looking woman is holding a pair of sunglasses and food.
# The woman is not empty handed.
#
# A man stands in a commercial kitchen cutting up a whole fish.
# The fish has not yet been filleted or prepared.
#
# Three people work on their laptops inside a store.
# The people are not outside.
#
# Asians stand in a group in from a banner and a traditional building.
# Some of the folks here are not Hispanic.
#
# A shirtless person with jeans is climbing a rocky mountainside.
# The person is not wearing a shirt.
#
# A shirtless boy is walking down the beach holding a large branch.
# A boy not wearing a shirt is walking holding a tree branch.
#
# A dog chases a sheep in an enclosure.
# A dog is not on a leash.
#
# A boy is leading donkeys on a path.
# The boy is not behind the donkeys.
#
# A main wearing a cowboy styled hat standing on a railroad.
# There are people visible who are not women.
#
# Young boy in a red shirt gropes around on the ground amongst the crowd.
# The boy is not standing straight.
#
# Person popping a wheelie on a dirt road.
# The road is not paved.
#
# A man leaning against a wall near a red car.
# The man is not standing straight.
#
# Two women standing by a table of vegetables.
# The women are not eating the vegetables.
#
# A man is wearing a colorfully painted jacket while atop a bicycle.
# A man atop a bicycle is not nude.
#
# A man wearing no shirt skateboarding on the street
# A man is not wearing a shirt.
#
# African relay runners running in a tight race.
# The runners are not from South America.
#
# A mysterious man is leaning against the white wall of a dimly lit tunnel.
# There is not a lot known about the man in question
#
# A woman in a black dress is sitting on stairs.
# A female is not standing up.
#
# a tan dog running through the grass with the background blurry
# The dog was not black.
#
# little girls in swimsuits are laughing
# The little girls are not taking a nap yet.
#
# Three dark dogs swimming and one of them has a ball.
# Two of the dogs do not have balls.
#
# A person is hanging in the air from the power lines.
# A person is not on the ground.
#
# A boy in dark clothing near a fountain water spout.
# The boy is not wearing white clothes.
#
# A man is in the ocean posing with his arms up in the air.
# A man is waving his hands like he does not care.
#
# The skinny brown dog is walking on a fallen tree.
# The dog is not walking on the ground.
#
# Soldiers and civilians sitting at dining table.
# The people are not standing.
#
# Three shoppers looking at product on a table at a outside market
# The market is not inside.
#
# A dog is walking along some dry cracked earth.
# A dog is walking next to ground that has not been watered.
#
# People are walking on the street in front of tall buildings at nighttime.
# The sun is not out.
#
# A group of guys are not he football field playing football.
# Guys are on a foot ball field.
#
# There are 5 brown dogs on leashes with their owners nearby.
# The dogs are not moving around
#
# Two toddlers in sports outfits sit amidst scattered laundry.
# The toddlers are not standing.
#
# Two men on their laptops not talking to each other.
# Two men are busy and not talking.
#
# The sidewalk closest to us is deserted.
# There are not many people on the sidewalk.
#
# A man on a skateboard is squatting next to a large dog.
# The man is not standing
#
# A person wearing sunglasses and a bright orange shirt walks down a wet sidewalk.
# The sidewalk is not dry.
#
# A family is sitting outside a store.
# A group of people are not standing
#
# A baby sleeping and sucking his finger.
# A baby is not awake.
#
# This young girl is making her way home.
# The girl is not home yet.
#
# Four women posing for a picture.
# Four women are not moving.
#
# Woman standing barefoot near a small hut and filling a jug with liquid.
# A woman has a container and is not wearing shoes.
#
# A man smiling as he is driving a large truck.
# The man is not in his home.
#
# Shirtless man in front of a brick building outside.
# A man is not wearing a shirt.
#
# The trailer is white
# The trailer is not all black.
#
# a man with a yellow shirt on stares in the distance
# The man is focused on something not in view.
#
# A man affectionately kissing a woman along a path
# The 2 people are not strangers.
#
# A man in a tractor wearing headphones driving down a paved street.
# The driver of the tractor is not plowing a field.
#
# A young woman is not wearing clothes and is taking a picture of herself.
# A young person is not wearing clothes and is taking a picture of herself.
#
# Young man in driveway holding small package.
# The package is not too heavy.
#
# Two women in green shirts are exiting a vehicle.
# Multiple people will soon not be in a vehicle.
#
# A young boy running on a field
# the person is not an adult
#
# Two young nurses display toys for children to play with.
# The nurses are not old.
#
# A middle eastern town with people.
# A town not in the United States with people.
#
# Two vehicles are parked outside a small grocery store.
# Two vehicles are not moving.
#
# Three people laying in the snow.
# Someone here is not standing upright.
#
# African women at work walking around with woven baskets on their head.
# The people shown are not Australian.
#
# two kids sleeping on a futon
# Two kids are not currently playing.
#
# A barefoot woman poses in front of a sylvan background.
# The woman is not wearing shoes.
#
# During the election party not all the guest attending are happy.
# Some of the election party guests are unhappy.
#
# During the election party not all the guest attending are happy.
# Some of the guests at the party are unhappy.
#
# During the election party not all the guest attending are happy.
# All the guests were not present at the election party.
#
# During the election party not all the guest attending are happy.
# Not all of those attending the election party are happy.
#
# Four people standing near a wall at night.
# The four people do not sit.
#
# A child jumps onto a bed.
# The little kid does not have his feet on the ground.
#
# Handicapped woman standing in front of a Tartuffe poster.
# Handicapped woman is not sitting down and is positioned next to the Tartuffe poster
#
# He is in the air on his skateboard.
# A man is not touching the ground.
#
# A child is sitting behind a makeshift table.
# Somebody who is depicted is not standing up.
#
# Siblings- the brothers always hate the pictures and the sisters always smile.
# The brothers does not like the pictures and sisters keep their smile
#
# A girl in a coat on a sled in the snow.
# She is not directly on the snow
#
# A brown dog with large ears is shaking its self while standing on sand.
# A brown dog is not standing still
#
# Some people in a subway train.
# These people are not in their car.
#
# A man in a white shirt does work at a table.
# The man is probably not working outside.
#
# There is a person and a dog amongst many trees.
# The person is outside and is not alone.
#
# People playing soccer in the sand.
# People are not on a soccer field.
#
# Young athlete in blue shows star potential during a close game.
# The game is not a blowout.
#
# A group of people gathered around in the dark.
# The people are not in the light.
#
# The brown and white dog nips at the yellow dog.
# A brown and white dog is not happy with a yellow dog.
#
# A boy is looking at a boat filled with sand.
# The boat is not seaworthy
#
# An unhappy toddler sitting on the sidewalk.
# The child is not amused.
#
# A man stands on boards on top of a huge ladder.
# The man is not standing on the ground.
#
# A woman jumps in the air as others walk behind her in the street.
# The woman is not inside.
#
# Two dogs in harnesses running in tall grass.
# The dog are not on the asphalt.
#
# The red lines are slanted.
# The red lines are not straight.
#
# The sky appears clear.
# It is not raining outside.
#
# A man with curly hair and red glasses.
# His glasses were not black.
#
# A man sits on steps in the shadows.
# There is a person who is not brightly lit.
#
# A man with no shirt sitting on a moped.
# The man is not riding a unicycle.
#
# There is a man in a white shirt and khaki pants in the background.
# The man in white and khaki is not the focus of the picture.
#
# A woman does not waste the nice day by reading on the beach.
# The weather is nice.
#
# Men and women sit in a meeting and listen to a presentation.
# People are not standing as they comprehend auditory noises.
#
# A woman in Asia looking at something.
# The woman is not blind.
#
# A bearded man shows off what he just cooked.
# The chef has not shaved in many days.
#
# A man without a shirt working on a rooftop.
# There is not bad weather outside for a man on a roof.
#
# The animals look very happy and healthy.
# The animals are not sick.
#
# The weather looks clear.
# There are not a lot of clouds outside.
#
# Tourists are walking past a van.
# The tourists are not from here.
#
# Man sitting at a computer.
# The man is not outside running.
#
# Three dogs run in the snow.
# The dogs are not sleep.
#
# An old man on a cart shopping for shoes
# The man is not walking.
#
# A car is sinking underwater in a lake or river.
# A vehicle is not where it should be.
#
# An elderly man speaks to a crowd.
# The elderly man is not sleeping.
#
# A man in a black dress is sitting and sleeping in a train.
# The man is not talking.
#
# A small child has tightly closed eyes.
# The child is not looking.
#
# Man and woman sitting in front of building on cloudy day
# the people are not running
#
# A woman asleep on the ground on a mat in front of a shrine.
# The woman is not awake
#
# A construction worker leaning against a post.
# A construction worker is not currently working.
#
# People sitting on benches on a sidewalk.
# There are humans who are not standing.
#
# A policeman from Madrid and an elderly woman looking away from the camera.
# The people are not facing the camera.
#
# A group of men are sitting around a table.
# A group of people are not standing.
#
# Man walks giant odd dog while small dog poops.
# The large dog is not pooping.
#
# Little girl is disinterested by what entices the crowd.
# A girl is not amused.
#
# Little girl is disinterested by what entices the crowd.
# A girl is not interested.
#
# A bride coming out of a car carrying a bouquet of flowers.
# The car is not moving.
#
# A man that is not wearing a shirt is brushing his teeth.
# The man is holding a toothbrush.
#
# A man with glasses and no shirt brushing his teeth.
# The man is not wearing a shirt.
#
# A man is leaping in the air while holding blue balloons.
# The man does not have both feet on the ground.
#
# A girl in a flowered dress peaking through some leaves.
# The girl is not blind.
#
# A couple watching a man sleep on a piece of art.
# The man is not awake.
#
# A woman in roller derby gear and a purple helmet skating into a turn.
# The woman is not wearing a full skirt.
#
# A young girl is jumping in the air at the beach.
# The girl is not touching the sand.
#
# A boy stands near a structure outside.
# A boy can be seen not indoors.
#
# A shirtless man lies on a park bench with his dog.
# The man is not wearing a shirt.
#
# Hispanics are on horseback trying to wrangle a free horse.
# The horse was not confined.
#
# A man in glasses completes a task beside a monitor that is not on.
# a man in glasses completes a task by a turned off monitor.
#
# A man shakes his arm at a group of people seated on a bench.
# the man does not like the people on the bench
#
# A man is perched on a rooftop.
# The man is not on the ground.
#
# A man in a Puma shirt holds a blond baby in a plaid dress.
# The baby is not on the ground
#
# A little girl with black hair pokes her head through tree branches.
# The girl is not bald.
#
# A man sitting on a chair in an office.
# The person in the office is not standing on his feet.
#
# Two smiling girls stand on a dirt road in India.
# The road is not paved.

# %%
s1 = 'A fisherman using a cellphone on a boat.'
s2 = 'A man is on the street'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man in colorful shorts is surfing under a wave.'
s1 = 'A Man is eating food next to a child on a bench.'
s2 = 'A man is on the street'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A shirtless man skateboards on a ledge.'
s2 = 'A man is on the street'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man wearing a hat and boots is digging for something in the snow.'
s2 = 'A man is on the street'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man is on a boat.'
s2 = 'A man is outside'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man is on a bench.'
s2 = 'A man is outside'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man is on a skateboard.'
s2 = 'A man is outside'
sub_predict(encoder, decoder, s1, s2)

s1 = 'A man is in the snow.'
s2 = 'A man is outside'
sub_predict(encoder, decoder, s1, s2)
# Out:
# Sentence:  A fisherman using a cellphone on a boat.
# Predicted Entailment:  a man is on a boat
#
# Sentence:  A Man is eating food next to a child on a bench.
# Predicted Entailment:  a man is on a bench
#
# Sentence:  A shirtless man skateboards on a ledge.
# Predicted Entailment:  a man is on a skateboard
#
# Sentence:  A man wearing a hat and boots is digging for something in the snow.
# Predicted Entailment:  a man is in the snow
#
# Sentence:  A man is on a boat.
# Predicted Entailment:  a man is outside
#
# Sentence:  A man is on a bench.
# Predicted Entailment:  a man is outside
#
# Sentence:  A man is on a skateboard.
# Predicted Entailment:  a man is outside
#
# Sentence:  A man is in the snow.
# Predicted Entailment:  a man is outside

# %%
for item in decoder.tree:
    print(item.lower_, item.dep_, item.head, item.pword)
# Out:
# a det man a
# man nsubj stares woman
# stares ROOT stares dancing
# at prep stares near
# some det puddle the
# puddle pobj at men

# %%
for item in decoder.tree:
    probs = np.copy(item.probs)
    idx = np.argmax(probs)
    indices =  np.argpartition(probs.flatten(), -3)[-3:]
    print(decoder.idx_to_wrd[item.dep_][idx], [(decoder.idx_to_wrd[item.dep_][x], probs[x]) for x in indices])
# Out:
# a [('some', array([ 0.0110209])), ('a', array([ 0.5994186])), ('the', array([ 0.3875215]))]
# woman [('people', array([ 0.04091187])), ('women', array([ 0.13422822])), ('woman', array([ 0.69407103]))]
# dancing [('are', array([ 0.04799138])), ('is', array([ 0.0686365])), ('dancing', array([ 0.25484948]))]
# near [('in', array([ 0.11977326])), ('above', array([ 0.15794334])), ('near', array([ 0.23338426]))]
# the [('some', array([ 0.01722168])), ('a', array([ 0.06917259])), ('the', array([ 0.90544366]))]
# men [('women', array([ 0.08615071])), ('people', array([ 0.09178136])), ('men', array([ 0.20546084]))]

# %%
print(subvocabs['aux'])
# Out:
# {'outside', 'walks', 'been', 'enjoys', 'can', 'tie', 'wanna', 'may', 'n', 'ARE', 'outdoors', 'balancing', 'competing', 'be', 're', 'sleeping', 'Can', 'Men', 'help', 'sunshine', 'am', 'square', 'orange', 'Waves', 'lap', 'para', 'hawk', 'practices', 'goers', 'pep', 'rock', 'give', 'pretend', 'feels', 'likes', 'to', 'being', 'woman', 'band', 'tries', 'would', 'enjoy', 'ski', 's', 'dressed', 'outdoor', 'do', 'building', 'busy', 'park', 'Is', 'considers', 'stands', 'seafarer', 'love', 'concrete', 'swimming', 'Player', 'Will', 'bungee', 'walk', 'willing', 'To', 'TO', 'microwave', 'mask', 'will', 'ware', 'snow', 'runs', 'work', 'saliva', 'prepares', 'ride', 'are', 'doing', 'floats', 'hate', 'did', 'leans', 'might', 'adult', 'could', 'came', 'climbs', 'stare', 'handicapped', 'looks', 'match', 'ins', 'was', 'turned', 'does', 'must', 'jump', 'inhaling', 'sled', 'laying', 'gets', 'had', 'has', 'crew', 'unknowing', 'should', 'having', 'IS', 'jeep', 'helping', 'avoiding', 'wearing', 'id', 'both', 'birds', 'sits', 'is', 'hugging', 'd', 'like', 'getting', 'let', 'were', 'hang', 'shall', 'skateboarded', 'walking', 'goes', 'have', 'calmly', 'WERE', 'sitting'}

# %%
total = 0 
correct = 0

for item in train_data:
    encoder.forward_pass(item.sentence1)
    decoder.forward_pass(item.sentence2, encoder.get_root_embedding())
    
    for node in decoder.tree:
        total += 1
        if node.pword.lower() == node.lower_:
            correct += 1
            
accuracy = float(correct / total)
print(accuracy)
# Out:
# 0.6669988931826031

# %%
total = 0 
correct = 0

for item in test_data:
    encoder.forward_pass(item.sentence1)
    decoder.forward_pass(item.sentence2, encoder.get_root_embedding())
    
    for node in decoder.tree:
        total += 1
        if node.pword.lower() == node.lower_:
            correct += 1
            
accuracy = float(correct / total)
print(accuracy)
# Out:
# 0.6176445248556905

# %%
test_contra = [d for d in clean_test if d.label == 'contradiction'] # or d.label == 'neutral']

# %%
for item in snli.test_data:
    if 'bounces in a' in item.sentence1:
        print(item)
# Out:
# TrainingPair(sentence1='A girl bounces in a bounce house.', sentence2='A girl is bouncing around.', label='entailment')
# TrainingPair(sentence1='A girl bounces in a bounce house.', sentence2='A girl is bouncing alongside with another girl.', label='neutral')
# TrainingPair(sentence1='A girl bounces in a bounce house.', sentence2='A girl is bouncing around at a friend birthday party.', label='neutral')
